# %%
import pandas as pd
df= pd.read_excel('/Users/seanyoo/Desktop/insta_statistic_project/xlsx/insta_info.xlsx')

# %%
# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/seanyoo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/seanyoo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Data Preprocessing

# %%
#Check if there is any null value 
df.isnull().any()
# Out:
# url                False
# name                True
# follower_count     False
# following_count    False
# post_count         False
# description         True
# dtype: bool

# %%
df = df.fillna(" ")
df.isnull().any()
# Out:
# url                False
# name               False
# follower_count     False
# following_count    False
# post_count         False
# description        False
# dtype: bool

# %%
df.dtypes
# Out:
# url                object
# name               object
# follower_count      int64
# following_count     int64
# post_count          int64
# description        object
# dtype: object

# %%
df = df.sort_values(by='follower_count', ascending=False)

# %% [markdown]
# ## Data Visualization

# %%
channel_bar_graph = sns.barplot(x = 'name', y = 'follower_count', data = df.sort_values('follower_count', ascending=False)[0:10])
plot = channel_bar_graph.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 channel_bar_graph = sns.barplot(x = 'name', y = 'follower_count', data = df.sort_values('follower_count', ascending=False)[0:10])
# ----> 2 plot = channel_bar_graph.set_xticklabels(ax.get_xticklabels(), rotation=90)
#
# NameError: name 'ax' is not defined

# %% [markdown]
# ## WorldCloud

# %%
stop_words = set(stopwords.words('english'))
df['title_no_stopwords'] = df['Keywords'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
stop_words = set(stopwords.words('english'))
df['title_no_stopwords'] = df['description'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)
